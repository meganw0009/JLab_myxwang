# %%
import numpy as np
import matplotlib.pyplot as plt

ba1 = "barium_x_ray_spectra.Spe"
tb1 = "terbium_x_ray_spectra.Spe"
tb2 = "terbium_x_ray_spectra_2.Spe"
cu1 = "copper_x_ray_spectra.Spe"

ener_fit = {1: (0.044601,0.225354)}

data = np.genfromtxt(cu1, delimiter='\n', skip_header=12,skip_footer = 16)

plt.rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
plt.rc('text', usetex=True)

plt.bar(range(2047),data, color = '#1E88E5')
plt.xlabel("Bin Number", fontsize=14)
plt.ylabel("Counts", fontsize=14)
# Out:
# Text(0, 0.5, 'Counts')

# %%
# Working hypothesis for how to extract data is that in the file where it says
# $ENER_FIT:
# 0.225354 0.044601
# is y = b + mx where b = 0.225354 and m = 0.044601

def get_ener_at_bin(bin_num, m, b):
    return m*bin_num + b

# %%
get_ener_at_bin(715.47,*ener_fit[1])
# Out:
# 32.136031470000006
